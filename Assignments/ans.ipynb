# %% [markdown]
# ## QUE 1
# * create database school_db;
# *  use school_db;
# * create table student(id int auto_increment primary key,name varchar(50),age int,course varchar(50),city varchar(50),marks int);
# * insert into student(name,age,course,city,marks) values("Rahul Sharma",21,"Python","Indore",85),("Priya Verma",22,"Java","Bhopal",78),("Amit Singh",20,"Python","Indore",92),("Neha Patel",23,"Java","Pune",81),("Rohit Mehta",21,"Python","Mumbai",88),("Sneha Jain",22,"Java","Indore",76),("Karan Gupta",20,"Python","Delhi",95),("Pooja Mishra",23,"Java","Bhopal",84),("Ankit Tiwari",21,"Python","Pune",79),("Riya Kapoor",22,"Java","Mumbai",91);
# * desc student;
# *  select * from student;

# %% [markdown]
# ## QUE2
# *  create database company_db;
# *  use company_db;
# * create table employee(id int auto_increment primary key,name varchar(50),age int,department varchar(50),designation varchar(50),salary int);
# * insert into employee(name,age,department,designation,salary) values("Rahul Sharma",28,"IT","Developer", 55000),("Priya Verma",26, "HR","Executive", 42000),("Amit Singh",30,"IT","Team Lead",75000),("Neha Patel", 27, "Finance", "Accountant", 48000),("Rohit Mehta",32,"IT","Manager",90000),("Sneha Jain",25, "Marketing", "Executive", 40000),("Karan Gupta",29,"IT","Developer", 60000),("Pooja Mishra", 31,"HR","Manager", 80000),("Ankit Tiwari",28,"Finance"," Analyst", 65000),("Riya Kapoor", 27, "Marketing", "Manager", 70000);
# * desc employee;
# * select * from employee;

# %% [markdown]
# ## QUE 3
# * create database shop_db;
# *  use shop_db;
# * create table product(pid int primary key auto_increment,pname varchar(50),pcategory varchar(50),pbrand varchar(50),price int,quantity int);
# * insert into product(pname,pcategory,pbrand,price,quantity) values("Laptop" ,"Electronics", "Dell",55000,10),("Smartphone","Electronics","Samsung",25000,15),("Keyboard","Accessories","Logitech",1500,25),("Mouse","Accessories","HP",800,30),("Monitor","Electronics","LG",18000,12),("Headphones","Accessories","Sony",3000,20),("Printer","Electronics","Canon",12000,8),("Tablet","Electronics","Lenovo",22000,14),("Webcam","Accessories","Logitech" ,2500 ,18),("Speaker", "Accessories", "JBL",4500, 16);
# * desc product;
# * select * from product;
